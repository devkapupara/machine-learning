# %%
# %matplotlib inline
from matplotlib import pyplot
from matplotlib.pyplot import subplots
import pandas as pd
import numpy as np

# %% [markdown]
# This exercise relates to the College data set, which can be found in the file College.csv on the book website. It contains a number of variables for 777 different universities and colleges in the US. The variables are
# <ul>
#     <li>Private : Public/private indicator</li>
#     <li>Apps : Number of applications received</li>
#     <li>Accept : Number of applicants accepted</li>
#     <li>Enroll : Number of new students enrolled</li>
#     <li>Top10perc : New students from top 10 % of high school class • Top25perc : New students from top 25 % of high school class</li>
#     <li>F.Undergrad : Number of full-time undergraduates</li>
#     <li>P.Undergrad : Number of part-time undergraduates</li>
#     <li>Outstate : Out-of-state tuition</li>
#     <li>Room.Board : Room and board costs</li>
#     <li>Books : Estimated book costs</li>
#     <li>Personal : Estimated personal spending</li>
#     <li>PhD : Percent of faculty with Ph.D.s</li>
#     <li>Terminal : Percent of faculty with terminal degree</li>
#     <li>S.F.Ratio : Student/faculty ratio</li>
#     <li>perc.alumni : Percent of alumni who donate</li>
#     <li>Expend : Instructional expenditure per student</li>
#     <li>Grad.Rate : Graduation rate</li>
# </ul>

# %% [markdown]
# ### Use the `pd.read_csv()` function to read the data into Python. Call the loaded data college.

# %%
college = pd.read_csv('data/College.csv')
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# Look at the data used in the notebook by creating and running a new cell with just the code college in it. You should notice that the first column is just the name of each university in a column named something like Unnamed: 0. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later.

# %% [markdown]
# See that column 1 is `Unnamed: 0` which is meaningless. We want to convert it into something meaningful by changing to 'College' and then using it as index.

# %%
college2 = pd.read_csv('data/College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'}, axis = 1)
college3 = college3.set_index('College')

# %% [markdown]
# Use the `describe()` method of to produce a numerical summary of the variables in the data set.

# %%
college = college3
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# Use the `pd.plotting.scatter_matrix()` function to produce a scatterplotmatrixofthefirstcolumns[Top10perc, Apps, Enroll].

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']]);

# %% [markdown]
# Use the `boxplot()` method of college to produce side-by-side boxplots of Outstate versus Private.

# %%
college.Private = pd.Series(college.Private, dtype='category')
college.Private
# Out:
# College
# Abilene Christian University      Yes
# Adelphi University                Yes
# Adrian College                    Yes
# Agnes Scott College               Yes
# Alaska Pacific University         Yes
#                                  ...
# Worcester State College            No
# Xavier University                 Yes
# Xavier University of Louisiana    Yes
# Yale University                   Yes
# York College of Pennsylvania      Yes
# Name: Private, Length: 777, dtype: category
# Categories (2, object): ['No', 'Yes']

# %%
fig, ax = subplots(figsize=(8, 8))
college.boxplot('Outstate', by='Private', ax=ax);

# %% [markdown]
# Create a new qualitative variable, called Elite, by binning the Top10perc variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.

# %%
college['Elite'] = (college['Top10perc'] > 50)
college.value_counts('Elite')
# Out:
# Elite
# False    699
# True      78
# Name: count, dtype: int64

# %% [markdown]
# So 78 of the colleges are elite. Let us see what the Outstate tution looks against Elite status

# %%
fig, ax = subplots(figsize=(8,8))
college.boxplot('Outstate', 'Elite', ax=ax);

# %% [markdown]
# Use the `plot.hist()` method of college to produce some his- tograms with differing numbers of bins for a few of the quanti- tative variables. The command `plt.subplots(2, 2)` may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %%
college.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate', 'Elite'],
#       dtype='object')

# %%
fig, ax = subplots(2, 2, figsize=(10, 10))
key = 'Room.Board'
college.hist(key, bins=10, ax=ax[0, 0])
college.hist(key, bins=13, ax=ax[0, 1])
college.hist(key, bins=16, ax=ax[1, 0])
college.hist(key, bins=20, ax=ax[1, 1])
# Out:
# array([<Axes: title={'center': 'Room.Board'}>], dtype=object)

# %% [markdown]
# # Problem 9

# %% [markdown]
# This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %%
auto = pd.read_csv('data/Auto.csv', na_values=['?'])

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.0+ KB

# %% [markdown]
# (a) Which of the predictors are quantitative, and which are qualitative? <br>
# (b) What is the range of each quantitative predictor? You can answer this using the `min()` and `max()` methods in numpy. <br>
# (c) What is the mean and standard deviation of each quantitative predictor?

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  397.000000  397.000000    397.000000  392.000000   397.000000
# mean    23.515869    5.458438    193.532746  104.469388  2970.261965
# std      7.825804    1.701577    104.379583   38.491160   847.904119
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.000000   75.000000  2223.000000
# 50%     23.000000    4.000000    146.000000   93.500000  2800.000000
# 75%     29.000000    8.000000    262.000000  126.000000  3609.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    397.000000  397.000000  397.000000
# mean      15.555668   75.994962    1.574307
# std        2.749995    3.690005    0.802549
# min        8.000000   70.000000    1.000000
# 25%       13.800000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# (a) Cylinders, origin and year are qualitivate variable, remainders are quantitative. <br>
# (b) We can see the range for each from above by subtracting max and min. <br>
# (c) As above

# %%
sub_auto = auto.drop(auto.index[10:85])
sub_auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  322.000000  322.000000    322.000000  318.000000   322.000000
# mean    24.409317    5.378882    187.680124  101.235849  2936.807453
# std      7.913357    1.657398    100.120925   36.185088   810.987533
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000    100.250000   75.000000  2216.000000
# 50%     23.900000    4.000000    145.500000   90.500000  2797.500000
# 75%     30.650000    6.000000    250.000000  115.000000  3516.000000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration        year      origin
# count    322.000000  322.000000  322.000000
# mean      15.700621   77.130435    1.596273
# std        2.706436    3.131849    0.815572
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %%
auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
auto.cylinders = pd.Series(auto.cylinders, dtype='category')
auto.cylinders
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 392    4
# 393    4
# 394    4
# 395    4
# 396    4
# Name: cylinders, Length: 397, dtype: category
# Categories (5, int64): [3, 4, 5, 6, 8]

# %%
fig, ax = subplots(2, 2, figsize=(15, 10))
auto.boxplot('mpg', by='cylinders', ax=ax[0, 0])
auto.boxplot('horsepower', by='cylinders', ax=ax[0, 1])
auto.plot.scatter('horsepower', 'mpg', ax=ax[1,0])
auto.boxplot('acceleration', by='cylinders', ax=ax[1,1]);
